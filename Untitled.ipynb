# %%
import pandas as pd
import os
os.listdir(os.getcwd())
# Out:
# ['db', 'Untitled.ipynb', '.ipynb_checkpoints', 'etl', 'mushrooms.csv', 'sql']

# %%
data=pd.read_csv("mushrooms.csv")

# %%
data_dictionary={}
data_dictionary['cap-shape']={'b':'bell', 'c':'conical'}
data_dictionary['cap-shape']['x']='convex'
data_dictionary['cap-shape']['f']='flat'
data_dictionary['cap-shape']['k']='knobbed'
data_dictionary['cap-shape']['s']='sunken'

data_dictionary['cap-color']={}
data_dictionary['cap-color']['n']='brown'
data_dictionary['cap-color']['b']='buff'
data_dictionary['cap-color']['c']='cinnamon'
data_dictionary['cap-color']['g']='gray'
data_dictionary['cap-color']['r']='green'
data_dictionary['cap-color']['p']='pink'
data_dictionary['cap-color']['u']='purple'
data_dictionary['cap-color']['e']='red'
data_dictionary['cap-color']['w']='white'
data_dictionary['cap-color']['y']='yellow'

data_dictionary['odor']={}
data_dictionary['odor']['a']='almond'
data_dictionary['odor']['l']='anise'
data_dictionary['odor']['c']='creosote'
data_dictionary['odor']['y']='fishy'
data_dictionary['odor']['f']='foul'
data_dictionary['odor']['m']='musty'
data_dictionary['odor']['n']='none'
data_dictionary['odor']['p']='pungent'
data_dictionary['odor']['s']='spicy'

data_dictionary['gill-size']={}
data_dictionary['gill-size']['b']='broad'
data_dictionary['gill-size']['n']='narrow'


data_dictionary['gill-color']={}
data_dictionary['gill-color']['k']='black'
data_dictionary['gill-color']['n']='brown'
data_dictionary['gill-color']['b']='buff'
data_dictionary['gill-color']['h']='chocolate'
data_dictionary['gill-color']['g']='gray'
data_dictionary['gill-color']['r']='green'
data_dictionary['gill-color']['o']='orange'
data_dictionary['gill-color']['p']='pink'
data_dictionary['gill-color']['u']='purple'
data_dictionary['gill-color']['e']='red'
data_dictionary['gill-color']['w']='white'
data_dictionary['gill-color']['y']='yellow'


data_dictionary['stalk-color-above-ring']={}
data_dictionary['stalk-color-above-ring']['n']='brown'
data_dictionary['stalk-color-above-ring']['b']='buff'
data_dictionary['stalk-color-above-ring']['c']='cinnamon'
data_dictionary['stalk-color-above-ring']['g']='gray'
data_dictionary['stalk-color-above-ring']['o']='orange'
data_dictionary['stalk-color-above-ring']['p']='pink'
data_dictionary['stalk-color-above-ring']['e']='red'
data_dictionary['stalk-color-above-ring']['w']='white'
data_dictionary['stalk-color-above-ring']['y']='yellow'


data_dictionary['veil-color']={}
data_dictionary['veil-color']['n']='brown'
data_dictionary['veil-color']['o']='orange'
data_dictionary['veil-color']['w']='white'
data_dictionary['veil-color']['y']='yellow'



data_dictionary['ring-type']={}
data_dictionary['ring-type']['c']='cobwebby'
data_dictionary['ring-type']['e']='evanescent'
data_dictionary['ring-type']['f']='flaring'
data_dictionary['ring-type']['l']='large'
data_dictionary['ring-type']['n']='none'
data_dictionary['ring-type']['p']='pendant'
data_dictionary['ring-type']['s']='sheathing'
data_dictionary['ring-type']['z']='zone'



data_dictionary['spore-print-color']={}
data_dictionary['spore-print-color']['k']='black'
data_dictionary['spore-print-color']['n']='brown'
data_dictionary['spore-print-color']['b']='buff'
data_dictionary['spore-print-color']['h']='chocolate'
data_dictionary['spore-print-color']['r']='green'
data_dictionary['spore-print-color']['o']='orange'
data_dictionary['spore-print-color']['u']='purple'
data_dictionary['spore-print-color']['w']='white'
data_dictionary['spore-print-color']['y']='yellow'




data_dictionary['population']={}
data_dictionary['population']['a']='abundant'
data_dictionary['population']['c']='clustered'
data_dictionary['population']['n']='numerous'
data_dictionary['population']['s']='scattered'
data_dictionary['population']['v']='several'
data_dictionary['population']['y']='solitary'


data_dictionary['habitat']={}
data_dictionary['habitat']['g']='grasses'
data_dictionary['habitat']['l']='leaves'
data_dictionary['habitat']['m']='meadows'
data_dictionary['habitat']['p']='paths'
data_dictionary['habitat']['u']='urban'
data_dictionary['habitat']['w']='waste'
data_dictionary['habitat']['d']='woods'


import json
f=open('temp.json','w')
f.write(json.dumps(data_dictionary, indent=2))
f.close()

# %%
word_string='''cap-shape: bell=b,conical=c,convex=x,flat=f, knobbed=k,sunken=s 
cap-color: brown=n,buff=b,cinnamon=c,gray=g,green=r, pink=p,purple=u,red=e,white=w,yellow=y 
odor: almond=a,anise=l,creosote=c,fishy=y,foul=f, musty=m,none=n,pungent=p,spicy=s 
gill-size: broad=b,narrow=n 
gill-color: black=k,brown=n,buff=b,chocolate=h,gray=g, green=r,orange=o,pink=p,purple=u,red=e, white=w,yellow=y 
stalk-color-above-ring: brown=n,buff=b,cinnamon=c,gray=g,orange=o, pink=p,red=e,white=w,yellow=y 
veil-color: brown=n,orange=o,white=w,yellow=y 
ring-type: cobwebby=c,evanescent=e,flaring=f,large=l, none=n,pendant=p,sheathing=s,zone=z 
spore-print-color: black=k,brown=n,buff=b,chocolate=h,green=r, orange=o,purple=u,white=w,yellow=y 
population: abundant=a,clustered=c,numerous=n, scattered=s,several=v,solitary=y 
habitat: grasses=g,leaves=l,meadows=m,paths=p, urban=u,waste=w,woods=d'''

    for entry in word_string.split('\n'):
        column_name, keyvalues=entry.strip().split(':')
        keyvalues=keyvalues.strip()
        keyvalues=[x.strip() for x in keyvalues.split(',')]
        for x in keyvalues:
            key,value=x.split('=')

            key=key.strip()
            value=value.strip()
            if data_dictionary[column_name][value]==key:
                print (column_name,key,value)
            else:
                print ("NOOOO")
# Out:
# cap-shape bell b
# cap-shape conical c
# cap-shape convex x
# cap-shape flat f
# cap-shape knobbed k
# cap-shape sunken s
# cap-color brown n
# cap-color buff b
# cap-color cinnamon c
# cap-color gray g
# cap-color green r
# cap-color pink p
# cap-color purple u
# cap-color red e
# cap-color white w
# cap-color yellow y
# odor almond a
# odor anise l
# odor creosote c
# odor fishy y
# odor foul f
# odor musty m
# odor none n
# odor pungent p
# odor spicy s
# gill-size broad b
# gill-size narrow n
# gill-color black k
# gill-color brown n
# gill-color buff b
# gill-color chocolate h
# gill-color gray g
# gill-color green r
# gill-color orange o
# gill-color pink p
# gill-color purple u
# gill-color red e
# gill-color white w
# gill-color yellow y
# stalk-color-above-ring brown n
# stalk-color-above-ring buff b
# stalk-color-above-ring cinnamon c
# stalk-color-above-ring gray g
# stalk-color-above-ring orange o
# stalk-color-above-ring pink p
# stalk-color-above-ring red e
# stalk-color-above-ring white w
# stalk-color-above-ring yellow y
# veil-color brown n
# veil-color orange o
# veil-color white w
# veil-color yellow y
# ring-type cobwebby c
# ring-type evanescent e
# ring-type flaring f
# ring-type large l
# ring-type none n
# ring-type pendant p
# ring-type sheathing s
# ring-type zone z
# spore-print-color black k
# spore-print-color brown n
# spore-print-color buff b
# spore-print-color chocolate h
# spore-print-color green r
# spore-print-color orange o
# spore-print-color purple u
# spore-print-color white w
# spore-print-color yellow y
# population abundant a
# population clustered c
# population numerous n
# population scattered s
# population several v
# population solitary y
# habitat grasses g
# habitat leaves l
# habitat meadows m
# habitat paths p
# habitat urban u
# habitat waste w
# habitat woods d

# %%
import pandas as pd
import os,logging,json
import time


FILENAME='data_dictionary.json'
data_file_name='mushrooms.csv'
def read_file(filename):
    try:
        f=open(filename,'r')
        data=json.loads(f.read())
        f.close()
        return data
    except Exception as e:
        logging.error(e)
        logging.info("Please check file or fix json exiting")
        exit()

def read_data_file(filename):
    try:
        data=pd.read_csv(filename)
        return data
    except Exception as e:
        logging.error(e)
        logging.error("please ensure that %s file is present in %s",filename, os.getcwd())
        exit()


def validating_data(data, data_dictionary):

    logging.info("checking if the columns in data dictionary and data are consistent")
    columns=[col for col in data_dictionary]
    columns_in_data=list(data.columns)
    difference=list(set(columns).difference(columns_in_data))
    if len(difference)!=0:
        logging.warning("Some columns in data dictionary are not present in data file given")
        columns=list(set(columns).intersection(columns_in_data))

    if len(columns)==0:
        logging.error("Cannot process data with zero columns")
        exit()

    data=data[columns]
    for col in data.columns:
        values=list(data[col].values)
        present_in_dict=[val for val in data_dictionary[col]]
        
        key_difference=set(values).difference(set(present_in_dict))
        if (key_difference==set()):
            logging.info("Column %s successfully validated", col)
        else:
            logging.warning("Values not consistent with the data for %s", col)

    return data

# %%
start_time=time.time()
logging.basicConfig(format='%(filename)s - %(levelname)s - %(asctime)s %(message)s', datefmt='%m/%d/%Y %I:%M:%S %p', level=logging.DEBUG)

logging.info("Reading Data Dictionary")
data_dictionary=read_file(FILENAME)
    
data=read_data_file(data_file_name)

logging.info("validating and selecting required columns from data")
data=validating_data(data, data_dictionary)
# Out:
# <ipython-input-60-93fbae354b68> - INFO - 05/09/2021 01:00:23 AM Reading Data Dictionary
# <ipython-input-60-93fbae354b68> - INFO - 05/09/2021 01:00:23 AM validating and selecting required columns from data
# <ipython-input-59-4ac94bb03b3f> - INFO - 05/09/2021 01:00:23 AM checking if the columns in data dictionary and data are consistent
# <ipython-input-59-4ac94bb03b3f> - INFO - 05/09/2021 01:00:23 AM Column cap-shape successfully validated
# <ipython-input-59-4ac94bb03b3f> - INFO - 05/09/2021 01:00:23 AM Column cap-color successfully validated
# <ipython-input-59-4ac94bb03b3f> - INFO - 05/09/2021 01:00:23 AM Column odor successfully validated
# <ipython-input-59-4ac94bb03b3f> - INFO - 05/09/2021 01:00:23 AM Column gill-size successfully validated
# <ipython-input-59-4ac94bb03b3f> - INFO - 05/09/2021 01:00:23 AM Column gill-color successfully validated
# <ipython-input-59-4ac94bb03b3f> - INFO - 05/09/2021 01:00:23 AM Column stalk-color-above-ring successfully validated
# <ipython-input-59-4ac94bb03b3f> - INFO - 05/09/2021 01:00:23 AM Column veil-color successfully validated
# <ipython-input-59-4ac94bb03b3f> - INFO - 05/09/2021 01:00:23 AM Column ring-type successfully validated
# <ipython-input-59-4ac94bb03b3f> - INFO - 05/09/2021 01:00:23 AM Column spore-print-color successfully validated
# <ipython-input-59-4ac94bb03b3f> - INFO - 05/09/2021 01:00:23 AM Column population successfully validated
# <ipython-input-59-4ac94bb03b3f> - INFO - 05/09/2021 01:00:23 AM Column habitat successfully validated

# %%
def replacing_with_values(data,data_dictionary):
    for col in data.columns:
        data[col]=data[col].map(data_dictionary[col])
        
    return data

# %%
ndata=replacing_with_values(data, data_dictionary)

# %%
for x in ndata.columns:
    vals=set(ndata[x].values)
    
    other_vals=[data_dictionary[x][item] for item in data_dictionary[x]]
    
    if (set(vals)!=set(other_vals)):
        print (vals)
        print (set(other_vals))
        print (x)
# Out:
# {'none', 'flaring', 'large', 'evanescent', 'pendant'}
# {'zone', 'none', 'cobwebby', 'flaring', 'large', 'evanescent', 'sheathing', 'pendant'}
# ring-type
